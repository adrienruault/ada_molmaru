# %%
import pandas as pd
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import sklearn.linear_model as lm
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_val_score
# %matplotlib inline

# %% [markdown]
# First, we load the csv file. As the "white" parameter is not present, we add add a column "white" so that we can take this parameter into consideration. As written is the Dataset descritpion, there is only three color skin categories: "white", "hispanic" and "black". So we define as "white" all the subjects that are neither hispanic nor black.

# %%
df = pd.read_csv("./lalonde.csv")
df['white'] = ((df['hispan'] == 0) & (df['black'] == 0)).astype(int)

# %%
df_treat_1 = df[df['treat'] == 1]
re78_1 = df_treat_1['re78']
df_treat_0 = df[df['treat'] == 0]
re78_0 = df_treat_0['re78']
print("Median of real earnings in 1978:")
print("For people who did not participate in the job training program: ",re78_0.median())
print("For people who participated in the job training program: ", re78_1.median())
# Out:
# Median of real earnings in 1978:
# For people who did not participate in the job training program:  4975.505
# For people who participated in the job training program:  4232.309

# %% [markdown]
# We see that the median for the real earnings in 1978 is higher for people who did not participate in the training program. It seems that the training has no effect (or is even a factor of decreasing in the real earnings people can make).

# %%
fig = plt.figure()
plt.boxplot([re78_0, re78_1],labels=['0','1'],widths=[0.5,0.5])
fig.suptitle('')

# %% [markdown]
# Looking at the boxplot, we can once again assess that the training program has no effect on the earning someone can make.

# %%
mean_0 = df_treat_1['re78'].mean()
std_0 = df_treat_1['re78'].std()
mean_1 = df_treat_0['re78'].mean()
std_1 = df_treat_0['re78'].std()

print(mean_0, std_0, mean_1, std_1)
# Out:
# 6349.143530270269 7867.402217734684 6984.169742307697 7294.161790868392

# %%
plt.hist(df_treat_1['re78'], bins = 50, alpha = 0.5,normed=True)
plt.hist(df_treat_0['re78'], bins = 50, alpha = 0.5,normed=True)
plt.legend(['1','0'])

# %% [markdown]
# # 2. A closer look at the data

# %%
fig = plt.figure()
plt.boxplot([df_treat_0['re74'],df_treat_0['re75'],df_treat_1['re74'], df_treat_1['re75']],
            labels=['re74, treat = 0','re75, treat = 0','re74, treat = 1','re75, treat = 1'])
fig.suptitle('')

# %% [markdown]
# If we look at the real earnings in 1974-1975, we see that the samples are poorly distributed. The real earnings are significantly lower for the group that has participated in the training program. It indeed makes sense that only people that truly need to increase their real earnings will participate in such a training program. We thus get a bias in our dataset between people that participated and people that did not.

# %%
fig = plt.figure()
plt.boxplot([df_treat_0['age'], df_treat_1['age']], labels=['age repartition, treat = 0', 'age repartition, treat = 1'])
fig.suptitle('')

# %% [markdown]
# The age repartition is also unbalanced between the two groups. We have a larger.......................................................;

# %%
plt.hist(df_treat_1['educ'], bins = 20, alpha = 0.5,normed=True)
plt.hist(df_treat_0['educ'], bins = 20, alpha = 0.5,normed=True)
plt.legend(['1','0'])

# %%
plt.hist(df_treat_1['nodegree'], bins = 20, alpha = 0.5,normed=True)
plt.hist(df_treat_0['nodegree'], bins = 20, alpha = 0.5,normed=True)
plt.legend(['1','0'])

# %%
plt.hist(df_treat_1['black'], bins = 20, alpha = 0.5,normed=True)
plt.hist(df_treat_0['black'], bins = 20, alpha = 0.5,normed=True)
plt.legend(['1','0'])

# %%
plt.hist(df_treat_1['hispan'], bins = 20, alpha = 0.5,normed=True)
plt.hist(df_treat_0['hispan'], bins = 20, alpha = 0.5,normed=True)
plt.legend(['1','0'])

# %%
plt.hist(df_treat_1['white'], bins = 20, alpha = 0.5,normed=True)
plt.hist(df_treat_0['white'], bins = 20, alpha = 0.5,normed=True)
plt.legend(['1','0'])

# %% [markdown]
# # Propensity score matching

# %%
covariates = df.drop(['id', 'treat'], axis = 1)
treat = df['treat']
#id 	treat 	age 	educ 	black 	hispan 	married 	nodegree 	re74 	re75 	re78 	white

# %%
lr = lm.LogisticRegression(max_iter=10000,tol=1e-10)

# %%
precision = cross_val_score(lr, covariates, treat, cv=10, scoring="precision")
recall = cross_val_score(lr, covariates, treat, cv=10, scoring="recall")

print("Precision: %0.2f (+/- %0.2f)" % (precision.mean(), precision.std() * 2))
print("Recall: %0.2f (+/- %0.2f)" % (recall.mean(), recall.std() * 2))
# Out:
# Precision: 0.62 (+/- 0.47)
# Recall: 0.69 (+/- 0.48)

# %%
fit = lr.fit(covariates, treat)

# %%
probas = pd.DataFrame(fit.predict_proba(covariates))

# %%
probas
# Out:
#             0         1
# 0    0.398795  0.601205
# 1    0.776331  0.223669
# 2    0.215323  0.784677
# 3    0.254594  0.745406
# 4    0.327201  0.672799
# 5    0.303380  0.696620
# 6    0.354110  0.645890
# 7    0.245289  0.754711
# 8    0.287237  0.712763
# 9    0.939912  0.060088
# 10   0.283815  0.716185
# 11   0.248420  0.751580
# 12   0.345044  0.654956
# 13   0.370222  0.629778
# 14   0.342509  0.657491
# 15   0.297597  0.702403
# 16   0.255485  0.744515
# 17   0.269717  0.730283
# 18   0.275171  0.724829
# 19   0.289145  0.710855
# 20   0.298054  0.701946
# 21   0.880770  0.119230
# 22   0.878767  0.121233
# 23   0.286174  0.713826
# 24   0.256610  0.743390
# 25   0.409911  0.590089
# 26   0.244566  0.755434
# 27   0.722516  0.277484
# 28   0.232822  0.767178
# 29   0.291580  0.708420
# ..        ...       ...
# 584  0.320899  0.679101
# 585  0.311816  0.688184
# 586  0.910530  0.089470
# 587  0.951036  0.048964
# 588  0.899886  0.100114
# 589  0.897377  0.102623
# 590  0.309019  0.690981
# 591  0.904409  0.095591
# 592  0.452289  0.547711
# 593  0.857250  0.142750
# 594  0.798218  0.201782
# 595  0.287231  0.712769
# 596  0.321769  0.678231
# 597  0.945916  0.054084
# 598  0.920050  0.079950
# 599  0.956633  0.043367
# 600  0.342077  0.657923
# 601  0.751878  0.248122
# 602  0.955493  0.044507
# 603  0.367131  0.632869
# 604  0.596661  0.403339
# 605  0.948247  0.051753
# 606  0.891825  0.108175
# 607  0.266708  0.733292
# 608  0.901410  0.098590
# 609  0.864199  0.135801
# 610  0.891126  0.108874
# 611  0.878342  0.121658
# 612  0.563229  0.436771
# 613  0.901742  0.098258
#
# [614 rows x 2 columns]

# %% [markdown]
# # Balancing the dataset via matching

# %%
print('control population size:', len(df_treat_0), '\ntreated population size:', len(df_treat_1))
# Out:
# control population size: 429
# treated population size: 185

# %%
import networkx as nx
from networkx.algorithms import bipartite

# %%
edges = []
for i in df_treat_0.index:
    for j in df_treat_1.index:
        edges.append((i,j,1-abs(probas.loc[i][1] - probas.loc[j][1])))

# %%
B = nx.Graph()
B.add_nodes_from(df_treat_0.index)
B.add_nodes_from(df_treat_1.index)
B.add_weighted_edges_from(edges)

# %%
edges_matching = nx.algorithms.max_weight_matching(B)

# %%
edges_matching
# Out:
# {0: 253,
#  1: 389,
#  2: 363,
#  3: 559,
#  4: 408,
#  5: 424,
#  6: 409,
#  7: 232,
#  8: 540,
#  9: 193,
#  10: 595,
#  11: 201,
#  12: 375,
#  13: 425,
#  14: 278,
#  15: 437,
#  16: 320,
#  17: 357,
#  18: 539,
#  19: 334,
#  20: 280,
#  21: 279,
#  22: 563,
#  23: 435,
#  24: 573,
#  25: 414,
#  26: 422,
#  27: 455,
#  28: 565,
#  29: 525,
#  30: 404,
#  31: 550,
#  32: 372,
#  33: 475,
#  34: 318,
#  35: 572,
#  36: 341,
#  37: 282,
#  38: 538,
#  39: 585,
#  40: 571,
#  41: 286,
#  42: 558,
#  43: 474,
#  44: 450,
#  45: 200,
#  46: 552,
#  47: 458,
#  48: 594,
#  49: 229,
#  50: 510,
#  51: 421,
#  52: 551,
#  53: 514,
#  54: 348,
#  55: 554,
#  56: 612,
#  57: 561,
#  58: 526,
#  59: 391,
#  60: 592,
#  61: 523,
#  62: 401,
#  63: 354,
#  64: 555,
#  65: 593,
#  66: 556,
#  67: 382,
#  68: 465,
#  69: 515,
#  70: 263,
#  71: 418,
#  72: 260,
#  73: 411,
#  74: 281,
#  75: 541,
#  76: 415,
#  77: 368,
#  78: 607,
#  79: 371,
#  80: 603,
#  81: 557,
#  82: 290,
#  83: 373,
#  84: 453,
#  85: 383,
#  86: 542,
#  87: 243,
#  88: 589,
#  89: 536,
#  90: 361,
#  91: 576,
#  92: 410,
#  93: 521,
#  94: 519,
#  95: 588,
#  96: 452,
#  97: 582,
#  98: 596,
#  99: 211,
#  100: 440,
#  101: 250,
#  102: 199,
#  103: 462,
#  104: 402,
#  105: 609,
#  106: 583,
#  107: 294,
#  108: 343,
#  109: 518,
#  110: 230,
#  111: 215,
#  112: 469,
#  113: 532,
#  114: 444,
#  115: 400,
#  116: 268,
#  117: 564,
#  118: 190,
#  119: 451,
#  120: 584,
#  121: 192,
#  122: 302,
#  123: 486,
#  124: 247,
#  125: 535,
#  126: 537,
#  127: 477,
#  128: 606,
#  129: 479,
#  130: 517,
#  131: 342,
#  132: 445,
#  133: 568,
#  134: 405,
#  135: 189,
#  136: 219,
#  137: 412,
#  138: 283,
#  139: 295,
#  140: 370,
#  141: 492,
#  142: 529,
#  143: 600,
#  144: 392,
#  145: 611,
#  146: 225,
#  147: 484,
#  148: 380,
#  149: 355,
#  150: 448,
#  151: 393,
#  152: 423,
#  153: 366,
#  154: 386,
#  155: 311,
#  156: 560,
#  157: 275,
#  158: 570,
#  159: 461,
#  160: 590,
#  161: 364,
#  162: 449,
#  163: 212,
#  164: 329,
#  165: 315,
#  166: 344,
#  167: 367,
#  168: 575,
#  169: 395,
#  170: 601,
#  171: 376,
#  172: 610,
#  173: 604,
#  174: 256,
#  175: 464,
#  176: 581,
#  177: 324,
#  178: 442,
#  179: 335,
#  180: 569,
#  181: 511,
#  182: 369,
#  183: 466,
#  184: 208,
#  189: 135,
#  190: 118,
#  192: 121,
#  193: 9,
#  199: 102,
#  200: 45,
#  201: 11,
#  208: 184,
#  211: 99,
#  212: 163,
#  215: 111,
#  219: 136,
#  225: 146,
#  229: 49,
#  230: 110,
#  232: 7,
#  243: 87,
#  247: 124,
#  250: 101,
#  253: 0,
#  256: 174,
#  260: 72,
#  263: 70,
#  268: 116,
#  275: 157,
#  278: 14,
#  279: 21,
#  280: 20,
#  281: 74,
#  282: 37,
#  283: 138,
#  286: 41,
#  290: 82,
#  294: 107,
#  295: 139,
#  302: 122,
#  311: 155,
#  315: 165,
#  318: 34,
#  320: 16,
#  324: 177,
#  329: 164,
#  334: 19,
#  335: 179,
#  341: 36,
#  342: 131,
#  343: 108,
#  344: 166,
#  348: 54,
#  354: 63,
#  355: 149,
#  357: 17,
#  361: 90,
#  363: 2,
#  364: 161,
#  366: 153,
#  367: 167,
#  368: 77,
#  369: 182,
#  370: 140,
#  371: 79,
#  372: 32,
#  373: 83,
#  375: 12,
#  376: 171,
#  380: 148,
#  382: 67,
#  383: 85,
#  386: 154,
#  389: 1,
#  391: 59,
#  392: 144,
#  393: 151,
#  395: 169,
#  400: 115,
#  401: 62,
#  402: 104,
#  404: 30,
#  405: 134,
#  408: 4,
#  409: 6,
#  410: 92,
#  411: 73,
#  412: 137,
#  414: 25,
#  415: 76,
#  418: 71,
#  421: 51,
#  422: 26,
#  423: 152,
#  424: 5,
#  425: 13,
#  435: 23,
#  437: 15,
#  440: 100,
#  442: 178,
#  444: 114,
#  445: 132,
#  448: 150,
#  449: 162,
#  450: 44,
#  451: 119,
#  452: 96,
#  453: 84,
#  455: 27,
#  458: 47,
#  461: 159,
#  462: 103,
#  464: 175,
#  465: 68,
#  466: 183,
#  469: 112,
#  474: 43,
#  475: 33,
#  477: 127,
#  479: 129,
#  484: 147,
#  486: 123,
#  492: 141,
#  510: 50,
#  511: 181,
#  514: 53,
#  515: 69,
#  517: 130,
#  518: 109,
#  519: 94,
#  521: 93,
#  523: 61,
#  525: 29,
#  526: 58,
#  529: 142,
#  532: 113,
#  535: 125,
#  536: 89,
#  537: 126,
#  538: 38,
#  539: 18,
#  540: 8,
#  541: 75,
#  542: 86,
#  550: 31,
#  551: 52,
#  552: 46,
#  554: 55,
#  555: 64,
#  556: 66,
#  557: 81,
#  558: 42,
#  559: 3,
#  560: 156,
#  561: 57,
#  563: 22,
#  564: 117,
#  565: 28,
#  568: 133,
#  569: 180,
#  570: 158,
#  571: 40,
#  572: 35,
#  573: 24,
#  575: 168,
#  576: 91,
#  581: 176,
#  582: 97,
#  583: 106,
#  584: 120,
#  585: 39,
#  588: 95,
#  589: 88,
#  590: 160,
#  592: 60,
#  593: 65,
#  594: 48,
# 600      0.00000      0.0000    0.0
# 475     44.75806      0.0000    0.0
# ..           ...         ...    ...
# 367   1525.35500   6231.5730    1.0
# 465    182.61290   6423.6770    1.0
# 414    857.56450   3392.8600    1.0
# 451    293.61290   7698.9550    1.0
# 364   1555.79000   7675.3120    1.0
# 555      0.00000   6717.7450    1.0
# 389   1224.58100   6847.7850    1.0
# 393   1181.61300   5578.4180    1.0
# 563      0.00000   5841.4530    0.0
# 200  10929.92000   9922.9340    0.0
# 537      0.00000   3406.1600    1.0
# 386   1283.66100      0.0000    0.0
# 405    964.98390  12059.7300    1.0
# 581      0.00000   6494.6080    1.0
# 610      0.00000  19464.6100    0.0
# 391   1195.93500   3873.1210    0.0
# 606      0.00000   5551.8190    1.0
# 369   1491.33900    237.9140    1.0
# 526      0.00000   6290.6820    1.0
# 286   4191.14500   8957.9780    1.0
# 421    676.74190   5647.8710    1.0
# 279   4361.22600   3020.4730    0.0
# 435    485.17740   4112.5130    1.0
# 256   5279.66100  21602.8800    1.0
# 376   1394.66100   4975.5050    1.0
# 290   4010.32300  18133.1800    1.0
# 442    386.70970      0.0000    1.0
# 589      0.00000      0.0000    1.0
# 212   8441.37100  25048.9400    0.0
# 474     57.29032   1421.5730    1.0
#
# [185 rows x 12 columns]

# %%
plt.boxplot([df_match_control['re78'], df_treat_0['re78']])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f321cb26438>,
#   <matplotlib.lines.Line2D at 0x7f321caea860>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f321cb0bc50>,
#   <matplotlib.lines.Line2D at 0x7f321cb06470>,
#   <matplotlib.lines.Line2D at 0x7f321cafa7b8>,
#   <matplotlib.lines.Line2D at 0x7f321cafafd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f321caea710>,
#   <matplotlib.lines.Line2D at 0x7f321cb01fd0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f321cb72940>,
#   <matplotlib.lines.Line2D at 0x7f321cb011d0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f321cb20c18>,
#   <matplotlib.lines.Line2D at 0x7f321cb134e0>,
#   <matplotlib.lines.Line2D at 0x7f321caf3748>,
#   <matplotlib.lines.Line2D at 0x7f321caf3f60>]}

# %%
plt.boxplot([df_match_control['re74'],df_match_control['re75'],df_treat_1['re74'], df_treat_1['re75']],
            labels=['re74, treat = 0','re75, treat = 0','re74, treat = 1','re75, treat = 1'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f321c1d5b00>,
#   <matplotlib.lines.Line2D at 0x7f321c3ccef0>,
#   <matplotlib.lines.Line2D at 0x7f321c7e6358>,
#   <matplotlib.lines.Line2D at 0x7f321c7dce80>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f321c1f8e80>,
#   <matplotlib.lines.Line2D at 0x7f321c1ecd30>,
#   <matplotlib.lines.Line2D at 0x7f321c3dfe48>,
#   <matplotlib.lines.Line2D at 0x7f321c3dffd0>,
#   <matplotlib.lines.Line2D at 0x7f321c7f9208>,
#   <matplotlib.lines.Line2D at 0x7f321c7f90f0>,
#   <matplotlib.lines.Line2D at 0x7f321c3dde10>,
#   <matplotlib.lines.Line2D at 0x7f321c3ddf28>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f321c3ccda0>,
#   <matplotlib.lines.Line2D at 0x7f321c7f2a20>,
#   <matplotlib.lines.Line2D at 0x7f321c804518>,
#   <matplotlib.lines.Line2D at 0x7f321c3ecba8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f321c1ecef0>,
#   <matplotlib.lines.Line2D at 0x7f321c7c50b8>,
#   <matplotlib.lines.Line2D at 0x7f321c804b38>,
#   <matplotlib.lines.Line2D at 0x7f321c3ec588>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f321c1d5cc0>,
#   <matplotlib.lines.Line2D at 0x7f321c1f8cc0>,
#   <matplotlib.lines.Line2D at 0x7f321c3f2dd8>,
#   <matplotlib.lines.Line2D at 0x7f321c3f2f98>,
#   <matplotlib.lines.Line2D at 0x7f321c7edfd0>,
#   <matplotlib.lines.Line2D at 0x7f321c7f9828>,
#   <matplotlib.lines.Line2D at 0x7f321c7dc9e8>,
#   <matplotlib.lines.Line2D at 0x7f321c3dd7f0>]}

# %%
plt.boxplot([df_match_control['age'], df_match_control['age']], labels=['age repartition, treat = 0', 'age repartition, treat = 1'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f321c2ca080>,
#   <matplotlib.lines.Line2D at 0x7f321c658160>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f321c2c7a58>,
#   <matplotlib.lines.Line2D at 0x7f321c2c7c18>,
#   <matplotlib.lines.Line2D at 0x7f321c3a04a8>,
#   <matplotlib.lines.Line2D at 0x7f321c3a0390>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f321c651f98>,
#   <matplotlib.lines.Line2D at 0x7f321c7dc908>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f321c662438>,
#   <matplotlib.lines.Line2D at 0x7f322a118160>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f321c2ca9e8>,
#   <matplotlib.lines.Line2D at 0x7f321c2cabe0>,
#   <matplotlib.lines.Line2D at 0x7f321c661048>,
#   <matplotlib.lines.Line2D at 0x7f321c3909b0>]}

# %%
plt.hist(df_treat_1['educ'], bins = 20, alpha = 0.5,normed=True)
plt.hist(df_match_control['educ'], bins = 20, alpha = 0.5,normed=True)
plt.legend(['1','0'])

# %%
plt.hist(df_treat_1['black'], bins = 20, alpha = 0.5,normed=True)
plt.hist(df_match_control['black'], bins = 20, alpha = 0.5,normed=True)
plt.legend(['1','0'])

# %%
plt.hist(df_treat_1['hispan'], bins = 20, alpha = 0.5,normed=True)
plt.hist(df_match_control['hispan'], bins = 20, alpha = 0.5,normed=True)
plt.legend(['1','0'])

# %%
plt.hist(df_treat_1['white'], bins = 20, alpha = 0.5,normed=True)
plt.hist(df_match_control['white'], bins = 20, alpha = 0.5,normed=True)
plt.legend(['1','0'])

# %% [markdown]
# # Balancing the groups further

# %%
print(len(df_treat_0_BP), len(df_treat_1_BP))
# Out:
# 87 156

# %%
df_BP = df[df['black'] == 1]
df_treat_0_BP = df_BP[df_BP['treat'] == 0]
df_treat_1_BP = df_BP[df_BP['treat'] == 1]

# %%
covariates = df_BP.drop(['id', 'treat'], axis = 1)
treat = df_BP['treat']

# %%
lr = lm.LogisticRegression(max_iter=100000, tol=1e-6)
precision = cross_val_score(lr, covariates, treat, cv=10, scoring="precision")
recall = cross_val_score(lr, covariates, treat, cv=10, scoring="recall")

print("Precision: %0.2f (+/- %0.2f)" % (precision.mean(), precision.std() * 2))
print("Recall: %0.2f (+/- %0.2f)" % (recall.mean(), recall.std() * 2))
# Out:
# Precision: 0.57 (+/- 0.39)
# Recall: 0.82 (+/- 0.57)

# %%
fit = lr.fit(covariates,treat)

# %%
probas = pd.DataFrame(fit.predict_proba(covariates), index=df_BP.index)
probas
# Out:
#             0         1
# 0    0.318556  0.681444
# 2    0.238786  0.761214
# 3    0.241316  0.758684
# 4    0.335600  0.664400
# 5    0.313291  0.686709
# 6    0.413857  0.586143
# 7    0.226940  0.773060
# 8    0.306707  0.693293
# 10   0.293998  0.706002
# 11   0.281284  0.718716
# 12   0.372903  0.627097
# 13   0.306744  0.693256
# 14   0.378526  0.621474
# 15   0.303076  0.696924
# 16   0.283865  0.716135
# 17   0.267683  0.732317
# 18   0.300726  0.699274
# 19   0.332283  0.667717
# 20   0.292864  0.707136
# 23   0.278701  0.721299
# 24   0.257722  0.742278
# 25   0.338619  0.661381
# 26   0.232221  0.767779
# 28   0.231913  0.768087
# 29   0.284679  0.715321
# 30   0.328213  0.671787
# 31   0.352116  0.647884
# 32   0.404005  0.595995
# 33   0.421376  0.578624
# 34   0.386188  0.613812
# ..        ...       ...
# 539  0.349982  0.650018
# 540  0.507895  0.492105
# 551  0.311248  0.688752
# 552  0.378325  0.621675
# 554  0.339250  0.660750
# 556  0.304846  0.695154
# 557  0.421376  0.578624
# 558  0.303648  0.696352
# 559  0.344748  0.655252
# 560  0.291497  0.708503
# 564  0.387753  0.612247
# 565  0.276234  0.723766
# 570  0.340476  0.659524
# 571  0.380488  0.619512
# 572  0.209244  0.790756
# 573  0.260755  0.739245
# 576  0.328213  0.671787
# 582  0.344430  0.655570
# 583  0.289782  0.710218
# 584  0.324134  0.675866
# 585  0.321356  0.678644
# 590  0.319227  0.680773
# 592  0.363895  0.636105
# 595  0.292339  0.707661
# 596  0.341368  0.658632
# 600  0.386654  0.613346
# 603  0.390251  0.609749
# 604  0.602434  0.397566
# 607  0.260535  0.739465
# 612  0.549987  0.450013
#
# [243 rows x 2 columns]

# %%
edges = []
for i in df_treat_0_BP.index:
    for j in df_treat_1_BP.index:
        edges.append((i,j,1-abs(probas.loc[i][1] - probas.loc[j][1])))

# %%
B = nx.Graph()
B.add_nodes_from(df_treat_0_BP.index)
B.add_nodes_from(df_treat_1_BP.index)
B.add_weighted_edges_from(edges)

# %%
edges_matching = nx.algorithms.max_weight_matching(B)

# %%
df_match_control = df_treat_0.loc[edges_matching.keys()].dropna()

# %%
plt.boxplot([df_match_control['re78'], df_treat_0['re78']])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f321b339710>,
#   <matplotlib.lines.Line2D at 0x7f321b2cbe10>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f321b342ac8>,
#   <matplotlib.lines.Line2D at 0x7f321b342be0>,
#   <matplotlib.lines.Line2D at 0x7f321b2df630>,
#   <matplotlib.lines.Line2D at 0x7f321b2dfc50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f321b2cbd68>,
#   <matplotlib.lines.Line2D at 0x7f321b2e88d0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f321b2cb240>,
#   <matplotlib.lines.Line2D at 0x7f321b2dfd68>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f321b339e48>,
#   <matplotlib.lines.Line2D at 0x7f321b339f60>,
#   <matplotlib.lines.Line2D at 0x7f321b2d49b0>,
#   <matplotlib.lines.Line2D at 0x7f321b2d4fd0>]}
